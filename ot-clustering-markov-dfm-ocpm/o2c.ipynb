# %% [markdown]
# # Demonstration: o2c
# ## Prerequisite
# - Please install python libraries mentioned in requirements.txt, you can do it using pip install -r requirements.txt
#     - The code is tested using the versions that are specified in requirements.txt
# - Please download and unzip "SAP ERP IDES instance - O2C log" in JSON-OCEL format from http://ocel-standard.org and extrract it under datasets folder

# %%
import pm4py
from pm4py.visualization.ocel.ocdfg import visualizer as ocdfg_visualization
import processmining.discovery.ocdfg.markov as ocdfgmrkv
import processmining.log.ocel as ocelhelper

# %% [markdown]
# Let's start by discovering an ocdfg from the log file.

# %%
file_path = './datasets/o2c.jsonocel'
ocel = pm4py.read_ocel(file_path)
ocdfg = pm4py.discover_ocdfg(ocel)
ocdfg_visualization.apply(ocdfg)

# %% [markdown]
# Here, we calculate markov ocdfg, discover sets of possible clusters by tuning the threshold parameter:

# %%
ocdfg_markov = ocdfgmrkv.discover_ocdfg_markov(ocdfg)
sim_matrix = ocdfgmrkv.discover_similarity_matrix(ocdfg_markov)
tunned_similarity_clusters = ocdfgmrkv.similarity_tuning(sim_matrix)
st = ocdfgmrkv.get_similarity_tuning_plot(tunned_similarity_clusters)

# %% [markdown]
# In tuning, we can have multiple sets of similar clusters for different thresholds. For example, The clusters for the threshold between 0.01 and 0.15 are the same. This is needed to visualize the start and end of the line. In order to calculate the unique number of clusters with unique members, we optimize it based on a threshold that has a minimum value. The result is shown below.

# %%
res = ocdfgmrkv.get_optimised_similarity_tuning(sim_matrix)
for thresh, v in res.items():
    test_matrix = ocdfgmrkv.filter_matrix(sim_matrix, thresh)
    s = ocdfgmrkv.get_similarity_plot(test_matrix, size=(5,4), annotation=False)

# %% [markdown]
# Let's see the result of cluster discovery when we set the threshold to 39 %:

# %%
clusters_dic = ocdfgmrkv.discover_clusters(sim_matrix, 0.39)
clusters_dic
# Out:
# {0: {'BELNR', 'HANDL_UNIT'},
#  1: {'MATERIAL'},
#  2: {'CREDIT_MEMO_DOC'},
#  3: {'INDIP_REQ'},
#  4: {'INVOICE_PRO_FORMA'},
#  5: {'RETURNS_DELIVERY', 'RETURNS_DOC'},
#  6: {'ORD_WO_CHARGE'},
#  7: {'ITEM_PROPOSAL'},
#  8: {'DEBIT_MEMO_DOC', 'DEBIT_MEMO_REQ'},
#  9: {'WMS_TRANSFER'},
#  10: {'INFOSATZ'},
#  11: {'INVOICE_CANCEL'},
#  12: {'VERKBELEG'},
#  13: {'CREDIT_MEMO_REQ'},
#  14: {'CHARGE'},
#  15: {'EINKBELEG'}}

# %% [markdown]
# Let's discover the process for clusters with two members:

# %%
filtered_ocel = ocelhelper.filter_ocel(ocel, event_threshold=0, object_types={'DEBIT_MEMO_DOC', 'DEBIT_MEMO_REQ'})
filtered_ocdfg = pm4py.discover_ocdfg(filtered_ocel)
ocdfg_visualization.apply(filtered_ocdfg)

# %%
filtered_ocel = ocelhelper.filter_ocel(ocel, event_threshold=0, object_types={'BELNR', 'HANDL_UNIT'})
filtered_ocdfg = pm4py.discover_ocdfg(filtered_ocel)
ocdfg_visualization.apply(filtered_ocdfg)

# %%
filtered_ocel = ocelhelper.filter_ocel(ocel, event_threshold=0, object_types={'RETURNS_DELIVERY', 'RETURNS_DOC'})
filtered_ocdfg = pm4py.discover_ocdfg(filtered_ocel)
ocdfg_visualization.apply(filtered_ocdfg)
